# 'f.4238.1.7',
# 'f.4238.1.8',
# 'f.4238.1.9',
# 'f.4238.1.10',
# 'f.4238.1.11',
# 'f.4238.1.12',
# 'f.4238.1.13',
# 'f.4238.1.14',
# 'f.4238.1.15',
# 'f.4248.1.1',
# 'f.4248.1.2',
# 'f.4248.1.3',
# 'f.4248.1.4',
# 'f.4248.1.5',
# 'f.4248.1.6',
# 'f.4248.1.7',
# 'f.4248.1.8',
# 'f.4248.1.9',
# 'f.4248.1.10',
# 'f.4248.1.11',
# 'f.4248.1.12',
# 'f.4248.1.13',
# 'f.4248.1.14',
# 'f.4248.1.15',
# 'f.4257.0.0',
# 'f.4257.0.1',
# 'f.4257.0.2',
# 'f.4257.0.3',
# 'f.4257.0.4',
# 'f.4257.0.5',
# 'f.4257.0.6',
# 'f.4257.0.7',
# 'f.4257.0.8',
# 'f.4257.0.9',
# 'f.4257.0.10',
# 'f.4257.0.11',
# ...

# %%
mask = df.astype(str).apply(lambda x : x.str.match(r'\d{4}-\d{2}-\d{2} \d{2}\:\d{2}\:\d{2}').all())

# %%
date_cols
# Out:
# ['f.53.1.0',
#  'f.3060.1.0',
#  'f.3060.1.1',
#  'f.3060.1.2',
#  'f.3066.1.0',
#  'f.3066.1.1',
#  'f.3066.1.2',
#  'f.3166.0.6',
#  'f.3166.1.0',
#  'f.3166.1.1',
#  'f.3166.1.2',
#  'f.3166.1.3',
#  'f.3166.1.4',
#  'f.3166.1.5',
#  'f.3166.1.6',
#  'f.3166.2.4',
#  'f.3166.2.5',
#  'f.3166.2.6',
#  'f.4205.1.0',
#  'f.4238.1.1',
#  'f.4238.1.2',
#  'f.4238.1.3',
#  'f.4238.1.4',
#  'f.4238.1.5',
#  'f.4238.1.6',
#  'f.4238.1.7',
#  'f.4238.1.8',
#  'f.4238.1.9',
#  'f.4238.1.10',
#  'f.4238.1.11',
#  'f.4238.1.12',
#  'f.4238.1.13',
#  'f.4238.1.14',
#  'f.4238.1.15',
#  'f.4248.1.1',
#  'f.4248.1.2',
#  'f.4248.1.3',
#  'f.4248.1.4',
#  'f.4248.1.5',
#  'f.4248.1.6',
#  'f.4248.1.7',
#  'f.4248.1.8',
#  'f.4248.1.9',
#  'f.4248.1.10',
#  'f.4248.1.11',
#  'f.4248.1.12',
#  'f.4248.1.13',
#  'f.4248.1.14',
#  'f.4248.1.15',
#  'f.4257.0.0',
#  'f.4257.0.1',
#  'f.4257.0.2',
#  'f.4257.0.3',
#  'f.4257.0.4',
#  'f.4257.0.5',
#  'f.4257.0.6',
#  'f.4257.0.7',
#  'f.4257.0.8',
# ...

# %%
# chunk["f.53.1.0"]

# %%
# typedict = chunk.dtypes.to_dict()
# typedict
# typedict.update((k, str(v)) for k,v in typedict.items())
# typedict
import numpy as np
non_date_cols =  np.setdiff1d(chunk.columns,date_cols)
# chunk.dtypes[date_cols]
non_date_cols
chunk2 = chunk[non_date_cols]
typedict = chunk2.dtypes.to_dict()
# typedict
typedict.update((k, str(v)) for k,v in typedict.items())

# %%
for k,v in typedict.items():
    if v == "float64" or v == "int64":
        
        print("'"+k+"': float,")
    if v == "object":
        print("'"+k+"': object,")
# Out:
# 'f.100001.0.0': float,
# 'f.100001.1.0': float,
# 'f.100001.2.0': float,
# 'f.100001.3.0': float,
# 'f.100001.4.0': float,
# 'f.100002.0.0': float,
# 'f.100002.1.0': float,
# 'f.100002.2.0': float,
# 'f.100002.3.0': float,
# 'f.100002.4.0': float,
# 'f.100003.0.0': float,
# 'f.100003.1.0': float,
# 'f.100003.2.0': float,
# 'f.100003.3.0': float,
# 'f.100003.4.0': float,
# 'f.100004.0.0': float,
# 'f.100004.1.0': float,
# 'f.100004.2.0': float,
# 'f.100004.3.0': float,
# 'f.100004.4.0': float,
# 'f.100005.0.0': float,
# 'f.100005.1.0': float,
# 'f.100005.2.0': float,
# 'f.100005.3.0': float,
# 'f.100005.4.0': float,
# 'f.100006.0.0': float,
# 'f.100006.1.0': float,
# 'f.100006.2.0': float,
# 'f.100006.3.0': float,
# 'f.100006.4.0': float,
# 'f.100007.0.0': float,
# 'f.100007.1.0': float,
# 'f.100007.2.0': float,
# 'f.100007.3.0': float,
# 'f.100007.4.0': float,
# 'f.100008.0.0': float,
# 'f.100008.1.0': float,
# 'f.100008.2.0': float,
# 'f.100008.3.0': float,
# 'f.100008.4.0': float,
# ...

# %%
vs=list(typedict.values())
import numpy as np
np.unique(vs)
# Out:
# array(['float64', 'int64', 'object'],
#       dtype='<U7')

# %%
pd.to_datetime(chunk['f.132085.0.0'])
# Out:
# 0    NaT
# 1    NaT
# 2    NaT
# 3    NaT
# 4    NaT
# 5    NaT
# 6    NaT
# 7    NaT
# 8    NaT
# 9    NaT
# 10   NaT
# 11   NaT
# 12   NaT
# 13   NaT
# 14   NaT
# 15   NaT
# 16   NaT
# 17   NaT
# 18   NaT
# 19   NaT
# 20   NaT
# 21   NaT
# 22   NaT
# 23   NaT
# 24   NaT
# 25   NaT
# 26   NaT
# 27   NaT
# 28   NaT
# 29   NaT
#       ..
# 70   NaT
# 71   NaT
# 72   NaT
# 73   NaT
# 74   NaT
# 75   NaT
# 76   NaT
# 77   NaT
# 78   NaT
# 79   NaT
# 80   NaT
# 81   NaT
# 82   NaT
# 83   NaT
# 84   NaT
# 85   NaT
# 86   NaT
# 87   NaT
# 88   NaT
# 89   NaT
# 90   NaT
# 91   NaT
# 92   NaT
# 93   NaT
# 94   NaT
# 95   NaT
# 96   NaT
# 97   NaT
# 98   NaT
# 99   NaT
# Name: f.132085.0.0, dtype: datetime64[ns]

# %%
cohort = pd.read_csv("clinical_data/cohort_ids.csv")
cohort.shape

# %%
cohort
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6e5140107969> in <module>()
# ----> 1 cohort
#
# NameError: name 'cohort' is not defined

# %%
df = df.loc[df["f.eid"].isin(cohort)]
