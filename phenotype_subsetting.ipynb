# %%
import pandas as pd

# %%
cohort = list(pd.read_csv("clinical_data/cohort_ids.csv",header=None)[0].values)
len(cohort)
# Out:
# 181978

# %%
df = pd.DataFrame()
for i,chunk in enumerate(pd.read_csv("clinical_data/ukb45951.tab",sep="\t",chunksize=1000,low_memory=False)):
    chunk = chunk.loc[chunk["f.eid"].isin(cohort)]
    df = df.append(chunk)
    print(df.shape[0]/len(cohort)*100,end="\r")
# Out:
# 11.1925617382320945
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-bd79e1fcb283> in <module>()
#       2 for i,chunk in enumerate(pd.read_csv("clinical_data/ukb45951.tab",sep="\t",chunksize=1000,low_memory=False)):
#       3     chunk = chunk.loc[chunk["f.eid"].isin(cohort)]
# ----> 4     df = df.append(chunk)
#       5     print(df.shape[0]/len(cohort)*100,end="\r")
#
# /share/software/user/open/py-scipystack/1.0_py36/lib/python3.6/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity)
#    4433             to_concat = [self, other]
#    4434         return concat(to_concat, ignore_index=ignore_index,
# -> 4435                       verify_integrity=verify_integrity)
#    4436
#    4437     def join(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# ...

# %%
df.shape

# %%
print(df.shape)
df.head()

# %%
df.to_csv("clinical_data/cohort_full_phenotypes.csv",index=False)

# %%
cols = [x for x in df.columns if x.split(".")[-1]=="1"]
len(cols)

# %%
df = df[cols]
df.to_csv("clinical_data/cohort_first_instance_phenotypes.csv",index=False)

# %%
print(df.shape)
df.head()

# %%
df = df.append(chunk)
df
# Out:
#        f.eid  f.3.0.0  f.3.1.0  f.3.2.0  f.3.3.0  f.4.0.0  f.4.1.0  f.4.2.0  \
# 3    1000047      348      NaN      NaN      NaN    563.0      NaN    482.0
# 4    1000050      321      NaN      NaN      NaN    446.0      NaN      NaN
# 5    1000068      312      NaN      NaN      NaN    578.0      NaN      NaN
# 8    1000094      515      NaN      NaN      NaN    740.0      NaN      NaN
# 13   1000145      580      NaN      NaN      NaN    458.0      NaN      NaN
# 14   1000158      448      NaN      NaN      NaN    616.0      NaN      NaN
# 17   1000187      429      NaN      NaN      NaN    539.0      NaN      NaN
# 19   1000208      427      NaN    425.0      NaN    813.0      NaN    548.0
# 23   1000243      624      NaN      NaN      NaN    526.0      NaN      NaN
# 29   1000300      398    403.0      NaN      NaN    731.0    483.0      NaN
# 35   1000369      482      NaN      NaN      NaN    857.0      NaN      NaN
# ...
